# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Mukhammad Ramadhani Costa
#
# My Desire Occupation: DATA ANALYST

# %%
### I love data science this is because the fact that data is the most inmportant thing in a growth of everything and to that fact i love to use data to 
### make a significant changes in the world.

# %% [markdown]
# # The cell below will print the data in the variable

# %%
name = input()
age = input ()
print('HELLO ' + name + " your age is " + age + " please welcome!")
# Out:
# mukhammad
# 28
# HELLO mukhammad your age is 28 please welcome!
